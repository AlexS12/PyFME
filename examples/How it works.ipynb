# %% [markdown]
# # Python Flight Mechanics Engine

# %% [markdown]
# This installs `pyfme` to be run in this online notebook

# %%
# !pip install git+https://github.com/AeroPython/PyFME.git

# %% [markdown]
# ## Aircraft

# %% [markdown]
# In order to perform a simulation, the first thing we need is an aircraft:

# %%
from pyfme.aircrafts import Cessna172

# %%
aircraft = Cessna172()

# %% [markdown]
# Aircraft will provide the simulator the forces, moments and inertial properties in order to perform the integration of the dynamic system equations:

# %%
print(f"Aircraft mass: {aircraft.mass} kg")
print(f"Aircraft inertia tensor: \n {aircraft.inertia} kg/m²")
# Out:
# Aircraft mass: 1043.2616 kg
# Aircraft inertia tensor:
#  [[ 1285.3154166      0.             0.        ]
#  [    0.          1824.9309607      0.        ]
#  [    0.             0.          2666.89390765]] kg/m²

# %%
print(f"forces: {aircraft.total_forces} N")
print(f"moments: {aircraft.total_moments} N·m")
# Out:
# forces: [ 0.  0.  0.] N
# moments: [ 0.  0.  0.] N·m

# %% [markdown]
# For the aircraft, in order to calculate its forces and moments it is necessary to set the controls values within the limits:

# %%
print(aircraft.controls)
# Out:
# {'delta_elevator': 0, 'delta_aileron': 0, 'delta_rudder': 0, 'delta_t': 0}

# %%
print(aircraft.control_limits)
# Out:
# {'delta_elevator': (-0.4537856055185257, 0.48869219055841229), 'delta_aileron': (-0.26179938779914941, 0.3490658503988659), 'delta_rudder': (-0.27925268031909273, 0.27925268031909273), 'delta_t': (0, 1)}

# %% [markdown]
# but also to provide and environment (ie. atmosphere, winds, gravity) and the aircraft state, which will also determine the aerodynamic contribution.

# %% [markdown]
# ## Environment

# %%
from pyfme.environment.atmosphere import ISA1976
from pyfme.environment.wind import NoWind
from pyfme.environment.gravity import VerticalConstant

# %%
atmosphere = ISA1976()
gravity = VerticalConstant()
wind = NoWind()

# %% [markdown]
# The atmosphere, wind and gravity model make up the environment:

# %%
from pyfme.environment import Environment

# %%
environment = Environment(atmosphere, gravity, wind)

# %% [markdown]
# The environment has an update method which given the state (ie. position, altitude...) updates the environment variables (ie. density, wind magnitude, gravity force...)

# %%
help(environment.update)
# Out:
# Help on method update in module pyfme.environment.environment:
#
# update(state) method of pyfme.environment.environment.Environment instance

# %% [markdown]
# ## State

# %% [markdown]
# Even if the state can be set manually by giving the position, attitude, velocity, angular velocities... Most of the times, the user will want to trim the aircraft in a stationary condition. The aircraft controls to flight in that condition will be also provided by the trimmer.

# %%
from pyfme.utils.trimmer import steady_state_trim

# %%
help(steady_state_trim)
# Out:
# Help on function steady_state_trim in module pyfme.utils.trimmer:
#
# steady_state_trim(aircraft, environment, pos, psi, TAS, controls, gamma=0, turn_rate=0, exclude=None, verbose=0)
#     Finds a combination of values of the state and control variables
#     that correspond to a steady-state flight condition.
#
#     Steady-state aircraft flight is defined as a condition in which all
#     of the motion variables are constant or zero. That is, the linear and
#     angular velocity components are constant (or zero), thus all
#      acceleration components are zero.
#
#     Parameters
#     ----------
#     aircraft : Aircraft
#         Aircraft to be trimmed.
#     environment : Environment
#         Environment where the aircraft is trimmed including atmosphere,
#         gravity and wind.
#     pos : Position
#         Initial position of the aircraft.
#     psi : float, opt
#         Initial yaw angle (rad).
#     TAS : float
#         True Air Speed (m/s).
#     controls : dict
#         Initial value guess for each control or fixed value if control is
#         included in exclude.
#     gamma : float, optional
#         Flight path angle (rad).
#     turn_rate : float, optional
#         Turn rate, d(psi)/dt (rad/s).
#     exclude : list, optional
#         List with controls not to be trimmed. If not given, every control
#         is considered in the trim process.
#     verbose : {0, 1, 2}, optional
#         Level of least_squares verbosity:
#             * 0 (default) : work silently.
#             * 1 : display a termination report.
#             * 2 : display progress during iterations (not supported by 'lm'
#               method).
#
#     Returns
#     -------
#     state : AircraftState
#         Trimmed aircraft state.
#     trimmed_controls : dict
#         Trimmed aircraft controls
#
#     Notes
#     -----
#     See section 3.4 in [1] for the algorithm description.
#     See section 2.5 in [1] for the definition of steady-state flight
#     condition.
#
#     References
#     ----------
#     .. [1] Stevens, BL and Lewis, FL, "Aircraft Control and Simulation",
#         Wiley-lnterscience.

# %%
from pyfme.models.state.position import EarthPosition

# %%
pos = EarthPosition(x=0, y=0, height=1000)
psi = 0.5  # rad
TAS = 45  # m/s
controls0 = {'delta_elevator': 0, 'delta_aileron': 0, 'delta_rudder': 0, 'delta_t': 0.5}

# %%
trimmed_state, trimmed_controls = steady_state_trim(
    aircraft,
    environment,
    pos,
    psi,
    TAS,
    controls0
)

# %%
trimmed_state
# Out:
# Aircraft State
# x_e: 0.00 m, y_e: 0.00 m, z_e: -1000.00 m
# theta: 0.076 rad, phi: 0.000 rad, psi: 0.500 rad
# u: 44.87 m/s, v: -0.00 m/s, w: 3.40 m/s
# P: 0.00 rad/s, Q: 0.00 rad/s, R: 0.00 rad/s
# u_dot: 0.00 m/s², v_dot: -0.00 m/s², w_dot: 0.00 m/s²
# P_dot: -0.00 rad/s², Q_dot: -0.00 rad/s², R_dot: 0.00 rad/s²

# %%
trimmed_controls
# Out:
# {'delta_aileron': -5.4944323898667417e-18,
#  'delta_elevator': -0.048951124635247853,
#  'delta_rudder': 2.3690975432909528e-17,
#  'delta_t': 0.57799667845248526}

# %% [markdown]
# Now, all the necessary elements in order to calculate forces and moments are available

# %%
# Environment conditions for the current state:
environment.update(trimmed_state)

# Forces and moments calculation:
forces, moments = aircraft.calculate_forces_and_moments(trimmed_state, environment, controls0)

# %%
forces, moments
# Out:
# (array([  1.48929757e-11,  -5.36867365e-18,   0.00000000e+00]),
#  array([ -5.23207465e-13,  -1.45503653e-11,   1.08678966e-15]))

# %% [markdown]
# The aircraft is trimmed indeed: the total forces and moments (aerodynamics + gravity + thrust) are zero

# %% [markdown]
# ## Simulation

# %% [markdown]
# In order to simulate the dynamics of the aircraft under certain inputs in an environment, the user can set up a simulation using a dynamic system:

# %%
from pyfme.models import EulerFlatEarth

# %%
system = EulerFlatEarth(t0=0, full_state=trimmed_state)

# %% [markdown]
# ### Constant Controls

# %% [markdown]
# Let's set the controls for the aircraft during the simulation. As a first step we will set them constant and equal to the trimmed values.

# %%
from pyfme.utils.input_generator import Constant

# %%
controls = controls = {
    'delta_elevator': Constant(trimmed_controls['delta_elevator']),
    'delta_aileron': Constant(trimmed_controls['delta_aileron']),
    'delta_rudder': Constant(trimmed_controls['delta_rudder']),
    'delta_t': Constant(trimmed_controls['delta_t'])
}

# %%
from pyfme.simulator import Simulation

# %%
sim = Simulation(aircraft, system, environment, controls)

# %% [markdown]
# Once the simulation is set, the propagation can be performed:

# %%
results = sim.propagate(10)
# Out:
# time: 100%|█████████▉| 9.999999999999831/10 [00:06<00:00,  1.44it/s]

# %% [markdown]
# The results are returned in a DataFrame:

# %%
results
# Out:
#                  Fx            Fy            Fz      Mach            Mx  \
# time
# 0.01   1.489298e-11  2.865280e-16  0.000000e+00  0.133756 -5.000214e-13
# 0.02   1.489298e-11  1.835425e-16  0.000000e+00  0.133756 -4.778178e-13
# 0.03   1.489298e-11 -2.955912e-16  0.000000e+00  0.133756 -4.565544e-13
# 0.04   1.489298e-11 -1.132942e-15  0.000000e+00  0.133756 -4.361907e-13
# 0.05   1.489298e-11 -2.311347e-15  0.000000e+00  0.133756 -4.166881e-13
# 0.06   1.489298e-11 -3.814381e-15  0.000000e+00  0.133756 -3.980095e-13
# 0.07   1.466560e-11 -5.626319e-15  1.818989e-12  0.133756 -3.801197e-13
# 0.08   1.443823e-11 -7.732114e-15  3.637979e-12  0.133756 -3.629847e-13
# 0.09   1.512035e-11 -1.012088e-14  9.094947e-12  0.133756 -3.465899e-13
# 0.10   1.512035e-11 -1.277799e-14  9.094947e-12  0.133756 -3.308972e-13
# 0.11   1.512035e-11 -1.568994e-14  1.091394e-11  0.133756 -3.158743e-13
# 0.12   1.523404e-11 -1.885447e-14  1.091394e-11  0.133756 -3.015422e-13
# 0.13   1.512035e-11 -2.224550e-14  1.273293e-11  0.133756 -2.877942e-13
# 0.14   1.523404e-11 -2.588328e-14  1.273293e-11  0.133756 -2.747698e-13
# 0.15   1.534772e-11 -2.969915e-14  1.273293e-11  0.133756 -2.621295e-13
# 0.16   1.534772e-11 -3.371123e-14  1.273293e-11  0.133756 -2.500196e-13
# 0.17   1.500666e-11 -3.790516e-14  1.818989e-11  0.133756 -2.383950e-13
# 0.18   1.512035e-11 -4.226821e-14  1.818989e-11  0.133756 -2.272239e-13
# 0.19   1.523404e-11 -4.680614e-14  1.818989e-11  0.133756 -2.165656e-13
# 0.20   1.512035e-11 -5.151172e-14  2.000888e-11  0.133756 -2.064035e-13
# 0.21   1.512035e-11 -5.637219e-14  2.182787e-11  0.133756 -1.966831e-13
# 0.22   1.534772e-11 -6.136575e-14  2.182787e-11  0.133756 -1.873208e-13
# 0.23   1.512035e-11 -6.648524e-14  2.364686e-11  0.133756 -1.783057e-13
# 0.24   1.512035e-11 -7.171213e-14  2.546585e-11  0.133756 -1.695741e-13
# 0.25   1.512035e-11 -7.705813e-14  2.546585e-11  0.133756 -1.612233e-13
# 0.26   1.523404e-11 -8.253001e-14  2.546585e-11  0.133756 -1.532959e-13
# 0.27   1.523404e-11 -8.810933e-14  2.728484e-11  0.133756 -1.457093e-13
# 0.28   1.512035e-11 -9.379468e-14  2.910383e-11  0.133756 -1.384719e-13
# 0.29   1.523404e-11 -9.957911e-14  2.910383e-11  0.133756 -1.315586e-13
# 0.30   1.512035e-11 -1.054525e-13  2.910383e-11  0.133756 -1.249320e-13
# 9.83   3.396464  388.198646  212.073887  -1000.0
# 9.84   3.396464  388.593558  212.289628  -1000.0
# 9.85   3.396464  388.988471  212.505370  -1000.0
# 9.86   3.396464  389.383383  212.721111  -1000.0
# 9.87   3.396464  389.778295  212.936853  -1000.0
# 9.88   3.396464  390.173207  213.152594  -1000.0
# 9.89   3.396464  390.568119  213.368336  -1000.0
# 9.90   3.396464  390.963031  213.584077  -1000.0
# 9.91   3.396464  391.357943  213.799819  -1000.0
# 9.92   3.396464  391.752856  214.015560  -1000.0
# 9.93   3.396464  392.147768  214.231302  -1000.0
# 9.94   3.396464  392.542680  214.447043  -1000.0
# 9.95   3.396464  392.937592  214.662785  -1000.0
# 9.96   3.396464  393.332504  214.878526  -1000.0
# 9.97   3.396464  393.727416  215.094268  -1000.0
# 9.98   3.396464  394.122329  215.310009  -1000.0
# 9.99   3.396464  394.517241  215.525751  -1000.0
# 10.00  3.396464  394.912153  215.741492  -1000.0
#
# [1000 rows x 39 columns]

# %%
# %matplotlib inline

# %%
kwargs = {'marker': '.',
          'subplots': True,
          'sharex': True,
          'figsize': (12, 6)}

# %%
results.plot(y=['x_earth', 'y_earth', 'height'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['psi', 'theta', 'phi'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['q0', 'q1', 'q2', 'q3'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['v_north', 'v_east', 'v_down'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['p', 'q', 'r'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['alpha', 'beta', 'TAS'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['Fx', 'Fy', 'Fz'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['Mx', 'My', 'Mz'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['elevator', 'aileron', 'rudder', 'thrust'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ### Doublet

# %% [markdown]
# Let's set the controls for the aircraft during the simulation. As a first step we will set them constant and equal to the trimmed values.

# %%
from pyfme.utils.input_generator import Doublet

# %%
de0 = trimmed_controls['delta_elevator']

# %%
controls = controls = {
    'delta_elevator': Doublet(t_init=2, T=1, A=0.1, offset=de0),
    'delta_aileron': Constant(trimmed_controls['delta_aileron']),
    'delta_rudder': Constant(trimmed_controls['delta_rudder']),
    'delta_t': Constant(trimmed_controls['delta_t'])
}

# %%
sim = Simulation(aircraft, system, environment, controls)

# %% [markdown]
# Once the simulation is set, the propagation can be performed:

# %%
results = sim.propagate(90)
# Out:
# time: 90.00000000000914it [00:59,  1.50it/s]

# %%
results.plot(y=['x_earth', 'y_earth', 'height'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['psi', 'theta', 'phi'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['q0', 'q1', 'q2', 'q3'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['v_north', 'v_east', 'v_down'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['p', 'q', 'r'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['alpha', 'beta', 'TAS'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['Fx', 'Fy', 'Fz'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['Mx', 'My', 'Mz'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
results.plot(y=['elevator', 'aileron', 'rudder', 'thrust'], **kwargs);
# Out:
# /home/asaez/miniconda3/envs/pyfme/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Propagating only one time step

# %%
dt = 0.05  # seconds
sim = Simulation(aircraft, system, environment, controls, dt)

# %%
results = sim.propagate(0.5)
results
# Out:
# time: 100%|█████████▉| 0.49999999999999994/0.5 [00:00<00:00,  3.36it/s]
#                 Fx            Fy            Fz      Mach            Mx  \
# time
# 0.05  1.466560e-11 -2.318226e-15  1.818989e-12  0.133756 -4.167205e-13
# 0.10  1.546141e-11 -1.275346e-14  1.091394e-11  0.133756 -3.307165e-13
# 0.50  3.396464  19.745608  10.787075  -1000.0
#
# [10 rows x 39 columns]

# %% [markdown]
# We can propagate for one time step even once the simulation has been propagated before:

# %%
results = sim.propagate(sim.time+dt)
results
# Out:
# time: 100%|██████████| 0.55/0.55 [00:00<00:00, 51.60it/s]
#                 Fx            Fy            Fz      Mach            Mx  \
# time
# 0.05  1.466560e-11 -2.318226e-15  1.818989e-12  0.133756 -4.167205e-13
# 0.10  1.546141e-11 -1.275346e-14  1.091394e-11  0.133756 -3.307165e-13
# 0.15  1.546141e-11 -2.968746e-14  1.273293e-11  0.133756 -2.620941e-13
# 0.20  1.546141e-11 -5.148946e-14  1.818989e-11  0.133756 -2.063307e-13
# 0.25  1.557510e-11 -7.708650e-14  2.182787e-11  0.133756 -1.614866e-13
# 0.30  1.568878e-11 -1.053956e-13  2.546585e-11  0.133756 -1.245945e-13
# 0.35  1.602984e-11 -1.358224e-13  2.910383e-11  0.133756 -9.522920e-14
# 0.40  1.602984e-11 -1.677902e-13  3.456080e-11  0.133756 -7.166550e-14
# 0.45  1.659828e-11 -2.007405e-13  3.637979e-11  0.133756 -5.230678e-14
# 0.50  1.682565e-11 -2.341757e-13  4.001777e-11  0.133756 -3.610751e-14
# 0.55  1.728040e-11 -2.680352e-13  4.183676e-11  0.133756 -2.361979e-14
#
#                 My            Mz   TAS           a       aileron   ...     \
# time                                                               ...
# 0.05 -1.211481e-11  1.444428e-14  45.0  336.434581 -5.494432e-18   ...
# 0.10 -9.664133e-12  1.748664e-14  45.0  336.434581 -5.494432e-18   ...
# 0.15 -7.189534e-12  3.035705e-14  45.0  336.434581 -5.494432e-18   ...
# 0.20 -5.817048e-12  4.177529e-14  45.0  336.434581 -5.494432e-18   ...
# 0.25 -3.934470e-12  4.019335e-14  45.0  336.434581 -5.494432e-18   ...
# 0.30 -2.279115e-12  4.693280e-14  45.0  336.434581 -5.494432e-18   ...
# 0.35 -1.249263e-12  4.100948e-14  45.0  336.434581 -5.494432e-18   ...
# 0.40 -1.472964e-14  3.845659e-14  45.0  336.434581 -5.494432e-18   ...
# 0.45  6.912957e-13  5.279284e-14  45.0  336.434581 -5.494432e-18   ...
# 0.50  1.333168e-12  4.056523e-14  45.0  336.434581 -5.494432e-18   ...
# 0.55  1.452475e-12  3.700375e-14  45.0  336.434581 -5.494432e-18   ...
#
#         thrust         u             v        v_down     v_east    v_north  \
# time
# 0.05  0.577997  44.87164 -1.915157e-15  8.881784e-16  21.574149  39.491215
# 0.10  0.577997  44.87164 -1.920609e-15  1.332268e-15  21.574149  39.491215
# 0.15  0.577997  44.87164 -1.929976e-15  1.776357e-15  21.574149  39.491215
# 0.20  0.577997  44.87164 -1.943139e-15  2.664535e-15  21.574149  39.491215
# 0.25  0.577997  44.87164 -1.960394e-15  3.552714e-15  21.574149  39.491215
# 0.30  0.577997  44.87164 -1.981719e-15  4.884981e-15  21.574149  39.491215
# 0.35  0.577997  44.87164 -2.007532e-15  6.217249e-15  21.574149  39.491215
# 0.40  0.577997  44.87164 -2.037226e-15  7.993606e-15  21.574149  39.491215
# 0.45  0.577997  44.87164 -2.070645e-15  9.769963e-15  21.574149  39.491215
# 0.50  0.577997  44.87164 -2.108159e-15  1.154632e-14  21.574149  39.491215
# 0.55  0.577997  44.87164 -2.149520e-15  1.376677e-14  21.574149  39.491215
#
#              w    x_earth    y_earth  z_earth
# time
# 0.05  3.396464   1.974561   1.078707  -1000.0
# 0.10  3.396464   3.949122   2.157415  -1000.0
# 0.15  3.396464   5.923682   3.236122  -1000.0
# 0.20  3.396464   7.898243   4.314830  -1000.0
# 0.25  3.396464   9.872804   5.393537  -1000.0
# 0.30  3.396464  11.847365   6.472245  -1000.0
# 0.35  3.396464  13.821925   7.550952  -1000.0
# 0.40  3.396464  15.796486   8.629660  -1000.0
# 0.45  3.396464  17.771047   9.708367  -1000.0
# 0.50  3.396464  19.745608  10.787075  -1000.0
# 0.55  3.396464  21.720168  11.865782  -1000.0
#
# [11 rows x 39 columns]

# %% [markdown]
# Notice that `results` will include the previous timesteps as well as the last one. To get just the last one one can use pandas `loc` or `iloc`:

# %%
results.iloc[-1]  # last time step
# Out:
# Fx             1.728040e-11
# Fy            -2.680352e-13
# Fz             4.183676e-11
# Mach           1.337556e-01
# Mx            -2.361979e-14
# My             1.452475e-12
# Mz             3.700375e-14
# TAS            4.500000e+01
# a              3.364346e+02
# aileron       -5.494432e-18
# alpha          7.554882e-02
# beta          -4.776711e-17
# elevator      -4.895112e-02
# height         1.000000e+03
# p             -7.865968e-17
# phi           -3.048989e-17
# pressure       8.987627e+04
# psi            5.000000e-01
# q             -1.297846e-15
# q0             9.682212e-01
# q1            -9.343316e-03
# q2             3.659139e-02
# q3             2.472275e-01
# q_inf          1.125555e+03
# r              7.502455e-18
# rho            1.111660e+00
# rudder         2.369098e-17
# temperature    2.816510e+02
# theta          7.554882e-02
# thrust         5.779967e-01
# u              4.487164e+01
# v             -2.149520e-15
# v_down         1.376677e-14
# v_east         2.157415e+01
# v_north        3.949122e+01
# w              3.396464e+00
# x_earth        2.172017e+01
# y_earth        1.186578e+01
# z_earth       -1.000000e+03
# Name: 0.55, dtype: float64

# %%
results.loc[sim.time]  # results for current simulation time
# Out:
# Fx             1.728040e-11
# Fy            -2.680352e-13
# Fz             4.183676e-11
# Mach           1.337556e-01
# Mx            -2.361979e-14
# My             1.452475e-12
# Mz             3.700375e-14
# TAS            4.500000e+01
# a              3.364346e+02
# aileron       -5.494432e-18
# alpha          7.554882e-02
# beta          -4.776711e-17
# elevator      -4.895112e-02
# height         1.000000e+03
# p             -7.865968e-17
# phi           -3.048989e-17
# pressure       8.987627e+04
# psi            5.000000e-01
# q             -1.297846e-15
# q0             9.682212e-01
# q1            -9.343316e-03
# q2             3.659139e-02
# q3             2.472275e-01
# q_inf          1.125555e+03
# r              7.502455e-18
# rho            1.111660e+00
# rudder         2.369098e-17
# temperature    2.816510e+02
# theta          7.554882e-02
# thrust         5.779967e-01
# u              4.487164e+01
# v             -2.149520e-15
# v_down         1.376677e-14
# v_east         2.157415e+01
# v_north        3.949122e+01
# w              3.396464e+00
# x_earth        2.172017e+01
# y_earth        1.186578e+01
# z_earth       -1.000000e+03
# Name: 0.55, dtype: float64
